# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_cd.png">

# %%
import joblib
import glob
import os
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# 1. Carga tus datos de prueba
df = pd.read_csv("datos/uber_test.csv")
df.head(2)
# Out:
#              pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-01-17 22:57:21+00:00        -73.975792        40.776299
# 1  2013-10-13 04:49:17+00:00        -73.978827        40.744816
#
#    dropoff_longitude  dropoff_latitude  passenger_count  pickup_year  \
# 0         -73.967140         40.788574                4         2015
# 1         -73.856187         40.727704                2         2013
#
#    pickup_month  pickup_weekday  pickup_hour pickup_season pickup_period  \
# 0             1               5           22        Winter         Night
# 1            10               6            4        Autumn         Night
#
#    geo_distance
# 0      1.547205
# 1     10.506739

# %%
X_test =df

# %%
modelo = joblib.load("modelos/uber/modelo_UBER_MLP_tunned.joblib")

# %%
y_pred = modelo.predict(X_test)

# %%
pd.DataFrame(y_pred, columns=["Prediccion"]).to_csv("predicciones_UBER_JoseAque.csv", index=False)

# %%
# #modelos
# ruta_modelos = "modelos/uber/"  # cámbiala a tu carpeta
# archivos_modelos = glob.glob(os.path.join(ruta_modelos, "*.joblib"))

# %%
# resultados = []
# for modelo_path in archivos_modelos:
#     # nombre del modelo a partir del archivo
#     nombre_modelo = os.path.basename(modelo_path).replace(".joblib", "")
    
#     # 2. cargar modelo
#     modelo = joblib.load(modelo_path)
    
#     # 3. predecir
#     y_pred = modelo.predict(X_test)
    
#     # 4. métricas
#     r2 = r2_score(y_test, y_pred)
#     mae = mean_absolute_error(y_test, y_pred)
#     mse = mean_squared_error(y_test, y_pred)
#     rmse = np.sqrt(mse)
    
#     resultados.append({
#         "modelo": nombre_modelo,
#         "r2": r2,
#         "MAE": mae,
#         "MSE": mse,
#         "RMSE": rmse
#     })

# # 5. Pasar a DataFrame para comparar
# df_resultados = pd.DataFrame(resultados).sort_values(by="r2", ascending=False)
# print(df_resultados)

# %%
# # Cargar el modelo
# modelo = joblib.load("modelos/modelo_SVM_tunned.joblib")

# # Hacer las predicciones
# y_pred = modelo.predict(X_test)

# # Guardar las predicciones en un archivo CSV
# pd.DataFrame(y_pred, columns=["Prediccion"]).to_csv("prediccionesUBER_JoseAque.csv", index=False)

# print("Archivo guardado correctamente.")
