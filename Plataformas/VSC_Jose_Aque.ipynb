# %% [markdown]
# # Ejemplo de notebook Jupyter

# %% [markdown]
# ## 1. Cargar los datos

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# En este notebook se utilizará la gráfica de la temperatura promedio esperada en la ciudad de Mérida a lo largo de este año 2025
#
# *Fuente:* https://www.ncei.noaa.gov/
# ![Imagen temperatura Mérida](figuras/merida_temperatura_prom.png)

# %%
# Leer datos del archivo datos.csv
data = pd.read_csv ("datos/datos.csv")

# %%
# Vista previa de las primeras 5 líneas de los datos cargados
data.head ()
# Out:
#        mes  temperatura_max  temperatura_min
# 0    enero               30               17
# 1  febrero               32               18
# 2    marzo               34               20
# 3    abril               36               21
# 4     mayo               37               23

# %% [markdown]
# ## 2. Graficar los datos

# %%
#Graficamos las variables
data.plot(x='mes', y=['temperatura_max', 'temperatura_min'], kind='line')
plt.show()
