# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h2 style="font-size:2em;color:#840700">   Análisis exploratorio con Folium  </h4></center>

# %% [markdown]
# <br><center><h1 style="font-size:2em;color:#2467C0"> Visualización geoespacial con  Folium </h1></center>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/MapaMerida.png" align="middle" style="width:550px"/></td>
# <td>
#
#
# Folium (https://python-visualization.github.io/folium/) es una de las librerías más asequibles para análisis y representación geoespacial, por la sencillez de la sintaxis.
#
#
# Una de las características que más atrae es que no necesita convertir el DataFrame en un GeoDataFrame. Solo teniendo una serie con la latitud y otra serie con la longitud del punto espacial, es suficiente para que Folium lo represente en un mapa.
#
# </td>
# </tr>
# </table>

# %% [markdown]
# # Folium

# %% [markdown]
# _**Folium**_ es una poderosa biblioteca de visualización de datos en Python que se creó principalmente para ayudar a visualizar datos *geoespaciales*. Con Folium, se puede crear un mapa de cualquier lugar del mundo siempre que se conozcan sus valores de *latitud* y *longitud*. Además, los mapas creados por _**Folium**_ son de naturaleza interactiva, por lo que se puede acercar y alejar después de renderizar el mapa, lo cual es una característica muy útil.

# %% [markdown]
# # Configuración inicial

# %% [markdown]
# Folium proporciona la clase ``folium.Map()`` que toma el parámetro de ubicación en términos de latitud y longitud, para generar un mapa a su alrededor. Entonces, tracemos un mapa de la ciudad de Merida con latitud y longitud como _21.0530 y -89.6332_ respectivamente:

# %%
import folium
mapa = folium.Map(location=[21.0530, -89.6332])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_162a3974475228a2a211bb5d43640bd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_162a3974475228a2a211bb5d43640bd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_162a3974475228a2a211bb5d43640bd9 = L.map(
#                 &quot;map_162a3974475228a2a211bb5d43640bd9&quot;,
#                 {
#                     center: [21.053, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56055e0e06f9cf109f67de575958f097 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56055e0e06f9cf109f67de575958f097.addTo(map_162a3974475228a2a211bb5d43640bd9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Puede ver que estos mapas son interactivos. Puede acercar y alejar haciendo clic en los botones positivo y negativo en la esquina superior izquierda del mapa. También puede arrastrar el mapa y ver diferentes regiones.
#
# A continuación, pasemos al segundo problema y cambiemos el nivel de zoom. De forma predeterminada, puede acercar y alejar tanto como desee. Además, el nivel de zoom inicial se fija en 10 (el mapa se traza con un zoom de 10x).  Para hacer esto, Folium nos da tres parámetros: ``zoom_start``, ``min_zoom`` y ``max_zoom``.
#
# Entonces, tracemos nuevamente el mapa de Mérida pero esta vez de con un nivel de zoom desde el inicio:

# %%
mapa = folium.Map(location=[20.966044459794052, -89.67315616496887],zoom_start=17)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61bd278293c60ff8535cda8c97f6e866 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61bd278293c60ff8535cda8c97f6e866&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61bd278293c60ff8535cda8c97f6e866 = L.map(
#                 &quot;map_61bd278293c60ff8535cda8c97f6e866&quot;,
#                 {
#                     center: [20.966044459794052, -89.67315616496887],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_041d9ed975c08b3fb57518f577b17768 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_041d9ed975c08b3fb57518f577b17768.addTo(map_61bd278293c60ff8535cda8c97f6e866);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora tracemos nuevamente el mapa de Mérida  con un nivel de zoom restringido:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12,min_zoom=10,max_zoom=13)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0570ef3b48a6322a4255d2127264225d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0570ef3b48a6322a4255d2127264225d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0570ef3b48a6322a4255d2127264225d = L.map(
#                 &quot;map_0570ef3b48a6322a4255d2127264225d&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e10cbfc4a0e5dbea4446e2a9468346d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 10,
#   &quot;maxZoom&quot;: 13,
#   &quot;maxNativeZoom&quot;: 13,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e10cbfc4a0e5dbea4446e2a9468346d5.addTo(map_0570ef3b48a6322a4255d2127264225d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marcadores en el mapa

# %% [markdown]
# Los marcadores son los elementos que se utilizan para marcar una ubicación en un mapa. Por ejemplo, cuando utiliza _Google Maps_ para la navegación, su ubicación se marca con un marcador y su destino se marca con otro marcador. Los marcadores se encuentran entre los elementos más importantes y útiles de un mapa.
#
# _**Folium**_ proporciona una clase  ``folium.Marker ()``  para trazar marcadores en un mapa. Simplemente pase la latitud y la longitud de la ubicación, mencione la ventana emergente y la información sobre herramientas y agréguela al mapa.
#
# Agregar marcadores es un proceso de dos pasos. Primero, debe crear un mapa base en el que se colocarán sus marcadores, y luego agregar sus marcadores. En el siguiente ejemplo se muestra su implementación junto con algunas opciones extras de visualización:

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025],popup='FIUADY').add_to(mapa)
folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)
folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)
folium.Marker(location=[21.013049480113864, -89.66682551455158],popup='<h3 style="color:red;">Instituto Tecnológico de Mérida, Campus Poniente</h3>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63906bd16bfba6f54751bbbd145c6759 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63906bd16bfba6f54751bbbd145c6759&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63906bd16bfba6f54751bbbd145c6759 = L.map(
#                 &quot;map_63906bd16bfba6f54751bbbd145c6759&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aabfcb5e9707215d0e2ed1cee3267b04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aabfcb5e9707215d0e2ed1cee3267b04.addTo(map_63906bd16bfba6f54751bbbd145c6759);
#
#
#             var marker_ff712fb792dbe32b74a364efa42d4a19 = L.marker(
#                 [21.04829, -89.64025],
#                 {
# }
#             ).addTo(map_63906bd16bfba6f54751bbbd145c6759);
#
#
#         var popup_5f8ad5bdba91bdb4648c0908c6392ec8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b77a22c9e111dda3f5ad26bd238efb65 = $(`&lt;div id=&quot;html_b77a22c9e111dda3f5ad26bd238efb65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_5f8ad5bdba91bdb4648c0908c6392ec8.setContent(html_b77a22c9e111dda3f5ad26bd238efb65);
#
#
#
#         marker_ff712fb792dbe32b74a364efa42d4a19.bindPopup(popup_5f8ad5bdba91bdb4648c0908c6392ec8)
#         ;
#
#
#
#
#             var marker_6a6a64adafcbe3b915ce2441d1c32a6d = L.marker(
#                 [20.96972, -89.62272],
#                 {
# }
#             ).addTo(map_63906bd16bfba6f54751bbbd145c6759);
#
#
#         var popup_eee51225b9c57865b7ad74fa03996016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4adec32d1eea52728abdfbf7f5cc804 = $(`&lt;div id=&quot;html_c4adec32d1eea52728abdfbf7f5cc804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_eee51225b9c57865b7ad74fa03996016.setContent(html_c4adec32d1eea52728abdfbf7f5cc804);
#
#
#
#         marker_6a6a64adafcbe3b915ce2441d1c32a6d.bindPopup(popup_eee51225b9c57865b7ad74fa03996016)
#         ;
#
#
#
#
#             marker_6a6a64adafcbe3b915ce2441d1c32a6d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d18cc666783158622006b3bd63a8cd86 = L.marker(
#                 [20.94167, -89.59466],
#                 {
# }
#             ).addTo(map_63906bd16bfba6f54751bbbd145c6759);
#
#
#         var popup_d9e5ea7a3257572a44d05b994f3b7a09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f64cbc7ac7f092122d730b84552c531 = $(`&lt;div id=&quot;html_1f64cbc7ac7f092122d730b84552c531&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_d9e5ea7a3257572a44d05b994f3b7a09.setContent(html_1f64cbc7ac7f092122d730b84552c531);
#
#
#
#         marker_d18cc666783158622006b3bd63a8cd86.bindPopup(popup_d9e5ea7a3257572a44d05b994f3b7a09)
#         ;
#
#
#
#
#             marker_d18cc666783158622006b3bd63a8cd86.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_979750db34f0423c0a9c316a8d370d2d = L.marker(
#                 [21.013049480113864, -89.66682551455158],
#                 {
# }
#             ).addTo(map_63906bd16bfba6f54751bbbd145c6759);
#
#
#         var popup_30fd829a05b505dacf07d87bef47c70e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f60bed569c86934b7d20cef599eb3c8 = $(`&lt;div id=&quot;html_6f60bed569c86934b7d20cef599eb3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:red;&quot;&gt;Instituto Tecnológico de Mérida, Campus Poniente&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_30fd829a05b505dacf07d87bef47c70e.setContent(html_6f60bed569c86934b7d20cef599eb3c8);
#
#
#
#         marker_979750db34f0423c0a9c316a8d370d2d.bindPopup(popup_30f

# %% [markdown]
# En el mapa anteriorcuando pasa el cursor sobre un marcador el texto que aparece se conoce como ``tooltip`` (información sobre herramienta)  y el texto cuando hace clic en un marcador se conoce como una ``popup`` (ventana emergente). Si se observa detenidamente, se ha  personalizado la información  de los marcadores 2 y 3.

# %% [markdown]
# ## Marcadores personalizados

# %% [markdown]
# Para mejorar la visualización puede cambiar el icono del marcador, Folium proporciona la clase ``folium.Icon()`` que se puede utilizar para crear iconos personalizados para marcadores. Puede elegir iconos entre una amplia gama de opciones.
#
# ``Icon()`` toma tres argumentos: color, prefijo e icono. El color se utiliza para cambiar el color del marcador, el prefijo se utiliza para seleccionar el proveedor de iconos (prefix='fa' para https://fontawesome.com/icons?d=gallery&m=free y  prefix='glyphicon' para  https://getbootstrap.com/docs/3.3/components/) y el icono se utiliza para seleccionar el nombre del icono.

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='glyphicon glyphicon-circle-arrow-down')   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40beab619567b5ad1d1673c2e3ac5c7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40beab619567b5ad1d1673c2e3ac5c7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40beab619567b5ad1d1673c2e3ac5c7b = L.map(
#                 &quot;map_40beab619567b5ad1d1673c2e3ac5c7b&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c24d9113da6ccbd9818242accc34d99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c24d9113da6ccbd9818242accc34d99.addTo(map_40beab619567b5ad1d1673c2e3ac5c7b);
#
#
#             var marker_b2ae69b0b9b9e88e4411c05b28e90c6b = L.marker(
#                 [21.04829, -89.64025],
#                 {
# }
#             ).addTo(map_40beab619567b5ad1d1673c2e3ac5c7b);
#
#
#             var icon_90088f15bed5f5e27cbc35a1a3dfc0ed = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;none&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_690253e09d714586968dbe3047d826dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bb92ceacab9d99835bd60444247ad86 = $(`&lt;div id=&quot;html_2bb92ceacab9d99835bd60444247ad86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_690253e09d714586968dbe3047d826dd.setContent(html_2bb92ceacab9d99835bd60444247ad86);
#
#
#
#         marker_b2ae69b0b9b9e88e4411c05b28e90c6b.bindPopup(popup_690253e09d714586968dbe3047d826dd)
#         ;
#
#
#
#
#                 marker_b2ae69b0b9b9e88e4411c05b28e90c6b.setIcon(icon_90088f15bed5f5e27cbc35a1a3dfc0ed);
#
#
#             var marker_7fba1005b913152d8ad96b021fa7babb = L.marker(
#                 [20.96972, -89.62272],
#                 {
# }
#             ).addTo(map_40beab619567b5ad1d1673c2e3ac5c7b);
#
#
#             var icon_fa6b9bb9f312636ac716f3e2f7f6f54f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_79cbcf90bfe7a64989c693bb55d6cef5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35e4188e8b37bc90b5ee3ec9fbcfc250 = $(`&lt;div id=&quot;html_35e4188e8b37bc90b5ee3ec9fbcfc250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_79cbcf90bfe7a64989c693bb55d6cef5.setContent(html_35e4188e8b37bc90b5ee3ec9fbcfc250);
#
#
#
#         marker_7fba1005b913152d8ad96b021fa7babb.bindPopup(popup_79cbcf90bfe7a64989c693bb55d6cef5)
#         ;
#
#
#
#
#             marker_7fba1005b913152d8ad96b021fa7babb.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7fba1005b913152d8ad96b021fa7babb.setIcon(icon_fa6b9bb9f312636ac716f3e2f7f6f54f);
#
#
#             var marker_805485b327761a45057113193a3b2865 = L.marker(
#                 [20.94167, -89.59466],
#                 {
# }
#             ).addTo(map_40beab619567b5ad1d1673c2e3ac5c7b);
#
#
#             var icon_23052f40c1be703f63bb3fc8c115c95e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;glyphicon glyphicon-circle-arrow-down&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_16ccffd552eda2613b3d90c7abe4611d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5de18f20e8a36367eed741ef3e7ba631 = $(`&lt;div id=&quot;html_5de18f20e8a36367eed741ef3e7ba631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_16ccffd552eda26

# %% [markdown]
# ## Marcadores  tipo circunferencia

# %% [markdown]
# Se realiza mediante la función ``folium.Circle``. Cada circunferencia tiene un tamaño relacionado con un valor específico, a través del parametro ``radius`` (metros).

# %%
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12 )
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)


folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f87c9495bfab569e8d50b12ebc79fd5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f87c9495bfab569e8d50b12ebc79fd5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f87c9495bfab569e8d50b12ebc79fd5d = L.map(
#                 &quot;map_f87c9495bfab569e8d50b12ebc79fd5d&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eddf217e79e207490a726920e10b9e51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eddf217e79e207490a726920e10b9e51.addTo(map_f87c9495bfab569e8d50b12ebc79fd5d);
#
#
#             var marker_813e784dd51af40d63f1c1de8f1460b6 = L.marker(
#                 [21.04829, -89.64025],
#                 {
# }
#             ).addTo(map_f87c9495bfab569e8d50b12ebc79fd5d);
#
#
#             var icon_fb40bf810be8e016e444de98c260079c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;none&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_87ccf370a610d47489888d9fe31d5dea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3555c4fba2a889324b6f596c439d6871 = $(`&lt;div id=&quot;html_3555c4fba2a889324b6f596c439d6871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_87ccf370a610d47489888d9fe31d5dea.setContent(html_3555c4fba2a889324b6f596c439d6871);
#
#
#
#         marker_813e784dd51af40d63f1c1de8f1460b6.bindPopup(popup_87ccf370a610d47489888d9fe31d5dea)
#         ;
#
#
#
#
#                 marker_813e784dd51af40d63f1c1de8f1460b6.setIcon(icon_fb40bf810be8e016e444de98c260079c);
#
#
#             var marker_bffc0e55ac107d672168c4d187b855c3 = L.marker(
#                 [20.96972, -89.62272],
#                 {
# }
#             ).addTo(map_f87c9495bfab569e8d50b12ebc79fd5d);
#
#
#             var icon_e78e356d04465947b609aa5a2401484b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b95ed0984a5b14013d938d722f22df6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f40bfdb7b2d4e71c4ad1d6845faa606d = $(`&lt;div id=&quot;html_f40bfdb7b2d4e71c4ad1d6845faa606d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_3b95ed0984a5b14013d938d722f22df6.setContent(html_f40bfdb7b2d4e71c4ad1d6845faa606d);
#
#
#
#         marker_bffc0e55ac107d672168c4d187b855c3.bindPopup(popup_3b95ed0984a5b14013d938d722f22df6)
#         ;
#
#
#
#
#             marker_bffc0e55ac107d672168c4d187b855c3.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_bffc0e55ac107d672168c4d187b855c3.setIcon(icon_e78e356d04465947b609aa5a2401484b);
#
#
#             var marker_942287b86a2bf444772da71bb481b87a = L.marker(
#                 [20.94167, -89.59466],
#                 {
# }
#             ).addTo(map_f87c9495bfab569e8d50b12ebc79fd5d);
#
#
#             var icon_f1a83326f24abc3c703d07883ce90b49 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c0278278070fd6e75d40af87ff9eab48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf6f4fd1c04ce19c8a26123f727d53ca = $(`&lt;div id=&quot;html_bf6f4fd1c04ce19c8a26123f727d53ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_c0278278070fd6e75d40af87ff9eab48.setContent(ht

# %% [markdown]
# # Estilo del mapa

# %% [markdown]
# El estilo predeterminado se encuentra con la opción **OpenStreetMap**, pero tambien cuenta con  **CartoDB Positron** y  **CartoDB Voyager**
#
# https://leaflet-extras.github.io/leaflet-providers/preview/

# %% [markdown]
# ### cartodb positron

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332], tiles="OPNVKarte" ,zoom_start=12)

 
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa230b9abbe6ced147bddf9b8415033d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa230b9abbe6ced147bddf9b8415033d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa230b9abbe6ced147bddf9b8415033d = L.map(
#                 &quot;map_aa230b9abbe6ced147bddf9b8415033d&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f6622470578a015e21e6fec6b490b40 = L.tileLayer(
#                 &quot;https://tileserver.memomaps.de/tilegen/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map \u003ca href=\&quot;https://memomaps.de/\&quot;\u003ememomaps.de\u003c/a\u003e \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/2.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e, map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f6622470578a015e21e6fec6b490b40.addTo(map_aa230b9abbe6ced147bddf9b8415033d);
#
#
#             var marker_14555662e47f13800fd1fc91c29beb85 = L.marker(
#                 [21.04829, -89.64025],
#                 {
# }
#             ).addTo(map_aa230b9abbe6ced147bddf9b8415033d);
#
#
#             var icon_ab0d98dfc9d0b7685208be0144fae321 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;none&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_14fe6a7dd86217f6d96668986e3d3ac3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b107bb50708384e115e4a267ab56a82 = $(`&lt;div id=&quot;html_2b107bb50708384e115e4a267ab56a82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_14fe6a7dd86217f6d96668986e3d3ac3.setContent(html_2b107bb50708384e115e4a267ab56a82);
#
#
#
#         marker_14555662e47f13800fd1fc91c29beb85.bindPopup(popup_14fe6a7dd86217f6d96668986e3d3ac3)
#         ;
#
#
#
#
#                 marker_14555662e47f13800fd1fc91c29beb85.setIcon(icon_ab0d98dfc9d0b7685208be0144fae321);
#
#
#             var marker_1d852b3534c5d72021534b735f0a80a1 = L.marker(
#                 [20.96972, -89.62272],
#                 {
# }
#             ).addTo(map_aa230b9abbe6ced147bddf9b8415033d);
#
#
#             var icon_de78459444052e70ee9729588ebc4ebf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9bc398da1e3679b12392224397348e48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_762d3c4a5bd00be23fc6a648f23b78d9 = $(`&lt;div id=&quot;html_762d3c4a5bd00be23fc6a648f23b78d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9bc398da1e3679b12392224397348e48.setContent(html_762d3c4a5bd00be23fc6a648f23b78d9);
#
#
#
#         marker_1d852b3534c5d72021534b735f0a80a1.bindPopup(popup_9bc398da1e3679b12392224397348e48)
#         ;
#
#
#
#
#             marker_1d852b3534c5d72021534b735f0a80a1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1d852b3534c5d72021534b735f0a80a1.setIcon(icon_de78459444052e70ee9729588ebc4ebf);
#
#
#             var marker_07396ffa23f0fd8dbc27e3e7a4e9f5bb = L.marker(
#                 [20.94167, -89.59466],
#                 {
# }
#             ).addTo(map_aa230b9abbe6ced147bddf9b8415033d);
#
#
#             var icon_b49cf69b4d3e0897bd94e082021048b8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_382ff254944f324c4f6073d9ea427a38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c9ae24c49e0721610b34348427f36df = $(`&lt;div id=&quot;html_1c9ae24c49e0721610b34348427f36df&quot; style=&quot;wid

# %% [markdown]
# ### Cartodb dark_matter

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332], tiles ='Cartodb dark_matter',  zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c9e92180beb79494610fd8209b1bb0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c9e92180beb79494610fd8209b1bb0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c9e92180beb79494610fd8209b1bb0d = L.map(
#                 &quot;map_1c9e92180beb79494610fd8209b1bb0d&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_801a0285c039aaa9197ccf20b578423c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_801a0285c039aaa9197ccf20b578423c.addTo(map_1c9e92180beb79494610fd8209b1bb0d);
#
#
#             var marker_85ef27b590b71197bb6f97bdaba80c43 = L.marker(
#                 [21.04829, -89.64025],
#                 {
# }
#             ).addTo(map_1c9e92180beb79494610fd8209b1bb0d);
#
#
#             var icon_4b130556804ce1bdb9f85e9aab33bb0d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;none&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_24a38187bff5f335d7cd7e9662a14427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59eb437725bb310947a2e8ea7116a88d = $(`&lt;div id=&quot;html_59eb437725bb310947a2e8ea7116a88d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_24a38187bff5f335d7cd7e9662a14427.setContent(html_59eb437725bb310947a2e8ea7116a88d);
#
#
#
#         marker_85ef27b590b71197bb6f97bdaba80c43.bindPopup(popup_24a38187bff5f335d7cd7e9662a14427)
#         ;
#
#
#
#
#                 marker_85ef27b590b71197bb6f97bdaba80c43.setIcon(icon_4b130556804ce1bdb9f85e9aab33bb0d);
#
#
#             var marker_c91fbdc343317ecf496ee08c3bcc2e28 = L.marker(
#                 [20.96972, -89.62272],
#                 {
# }
#             ).addTo(map_1c9e92180beb79494610fd8209b1bb0d);
#
#
#             var icon_755df303530052d59caa5e81f49bccab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2182ce0655bee7784b031db4d40bb027 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1020243ecc0291a9fb643bfe83897f9 = $(`&lt;div id=&quot;html_c1020243ecc0291a9fb643bfe83897f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_2182ce0655bee7784b031db4d40bb027.setContent(html_c1020243ecc0291a9fb643bfe83897f9);
#
#
#
#         marker_c91fbdc343317ecf496ee08c3bcc2e28.bindPopup(popup_2182ce0655bee7784b031db4d40bb027)
#         ;
#
#
#
#
#             marker_c91fbdc343317ecf496ee08c3bcc2e28.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c91fbdc343317ecf496ee08c3bcc2e28.setIcon(icon_755df303530052d59caa5e81f49bccab);
#
#
#             var marker_ee02699fe0890965679eb85e4944acad = L.marker(
#                 [20.94167, -89.59466],
#                 {
# }
#             ).addTo(map_1c9e92180beb79494610fd8209b1bb0d);
#
#
#             var icon_1b1162c6e17e476ef6e3033de826fd8c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a900e6a0684e4946a0a5f08521c4c134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f512cb42431b2180f3e37f2348e783b = $(`&lt;div id=&quot;html_1f512cb42431b2180f3e37f2348e783b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc
