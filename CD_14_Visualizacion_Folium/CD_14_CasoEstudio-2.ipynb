# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0">Caso de estudio 2: Diabetes tipo 2 en México</h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/diabetes.jpg" align="middle" style="width:350px"/></td>
# <td>
#
# La diabetes mellitus (diabetes tipo 2) es la segunda causa de muerte en México. De acuerdo con estadísticas del INEGI, en 2016 murieron 105 mil 574 mexicanos debido a la diabetes.
#
# En 2017 se registró una tasa de 405.12 casos de diabetes tipo 2 por cada 100 mil habitantes en México; mientras que en 2018, dicho indicador aumentó a 411.85.
#
# Las estadísticas de diabetes tipo 2 en México disponibles en el Anuario de Morbilidad de la Dirección General de Epidemiología revelan que en el último año aumentó 1.66 por ciento la incidencia de dicho padecimiento.
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# ## Conjunto de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar el archivo datos/mexico_diabetes2_2017-2018.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/mexico_diabetes2_2017-2018.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head()
# Out:
#                ENTIDAD IDNAME  INCIDENCIA 2018  INCIDENCIA 2017
# 0       Aguascalientes     AS           478.52           645.77
# 1      Baja California     BC           661.29           567.10
# 2  Baja California Sur     BS           341.94           314.56
# 3             Campeche     CC           336.50           305.56
# 4                 CDMX     DF           411.28           434.16

# %% [markdown]
# <div class="alert alert-success">
# ¿Cuales son los e estados con menor incidencia de casos en 2018?
# </div>

# %%
data.sort_values(by=['INCIDENCIA 2018'], ascending=True)
data.head()
# Out:
#                ENTIDAD IDNAME  INCIDENCIA 2018  INCIDENCIA 2017
# 0       Aguascalientes     AS           478.52           645.77
# 1      Baja California     BC           661.29           567.10
# 2  Baja California Sur     BS           341.94           314.56
# 3             Campeche     CC           336.50           305.56
# 4                 CDMX     DF           411.28           434.16

# %%
data.sort_values(by=['INCIDENCIA 2018'], ascending=True, inplace=True)
data.head()
# Out:
#        ENTIDAD IDNAME  INCIDENCIA 2018  INCIDENCIA 2017
# 20      Puebla     PL           241.09           244.85
# 21   Querétaro     QO           266.11           276.97
# 19      Oaxaca     OC           270.42           267.11
# 11  Guanajuato     GT           279.10           267.16
# 30     Yucatán     YN           319.98           308.35

# %% [markdown]
# <div class="alert alert-success">
# ¿Cuales son los e estados con mayor incidencia de casos en 2018?
# </div>

# %%
data.sort_values(by=['INCIDENCIA 2018'], ascending=False, inplace=True)
data.head()
# Out:
#             ENTIDAD IDNAME  INCIDENCIA 2018  INCIDENCIA 2017
# 27       Tamaulipas     TS           730.87           615.40
# 1   Baja California     BC           661.29           567.10
# 17          Nayarit     NT           620.71           488.03
# 9           Durango     DG           596.08           533.08
# 24          Sinaloa     SL           568.01           599.72

# %% [markdown]
# <div class="alert alert-success">
# Construya una grafica de barras con los diferentes estados para el 2018 y una en dode se pueda comparar con el 2017
# </div>

# %%
nombres = data['ENTIDAD'].values
valores = data['INCIDENCIA 2018'].values

plt.figure(figsize=(21, 3))
plt.bar(nombres, valores)
plt.xticks(rotation='vertical')
# Etiqueta de los ejes
plt.xlabel('Estados')
plt.ylabel('Número de casos de Diabetes tipo2')
#Titulo de la figura
plt.title('Comparación por estados')

plt.show()

# %%
nombres = data['ENTIDAD'].values
valores2018 = data['INCIDENCIA 2018'].values
valores2017 = data['INCIDENCIA 2017'].values
N=len(nombres) # Número de estados

# ind = Posicion en el eje
ind = np.arange(N)
# Ancho de la barra 
width = 0.3  

plt.figure(figsize=(21, 3))


# Plotting
plt.bar(ind, valores2018 , width, label='Casos 2018')
plt.bar(ind + width, valores2017, width, label='Casos 2017')

plt.ylabel('Número de casos')
plt.xlabel('Estados')
plt.title('Comparación por estados entre 2017 y 2018')

plt.xticks(ind + width / 2, nombres )
plt.xticks(rotation='vertical')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# Defina un nuevo parametro y agregue una nueva columna, para comparar la incidencia del 2018 y 2017
# </div>

# %%
data['Comparador'] = 100*(data['INCIDENCIA 2018']-data['INCIDENCIA 2017'])/data['INCIDENCIA 2017']
data.head()
# Out:
#             ENTIDAD IDNAME  INCIDENCIA 2018  INCIDENCIA 2017  Comparador
# 27       Tamaulipas     TS           730.87           615.40   18.763406
# 1   Baja California     BC           661.29           567.10   16.609064
# 17          Nayarit     NT           620.71           488.03   27.186853
# 9           Durango     DG           596.08           533.08   11.818114
# 24          Sinaloa     SL           568.01           599.72   -5.287467

# %% [markdown]
# <div class="alert alert-success">
# Defina un nuevo DataFrame, df_IDC, que contenga solo el ID y el parametro  "Comparador"
# </div>

# %%
#Defina las máscaras  mask_indicator , mask_2011
df_IDC = data[['IDNAME','Comparador']]
df_IDC
# Out:
#    IDNAME  Comparador
# 27     TS   18.763406
# 1      BC   16.609064
# 17     NT   27.186853
# 9      DG   11.818114
# 24     SL   -5.287467
# 16     MS   -3.599706
# 8      CM   45.449089
# 7      CL   -4.600880
# 6      CH   12.481944
# 0      AS  -25.899314
# 31     ZS   -4.287084
# 29     VZ    8.003400
# 28     TL   29.255847
# 18     NL   22.792262
# 23     SP   -3.744041
# 14     JC   -7.391562
# 12     GR   -3.882364
# 4      DF   -5.269947
# 25     SR    2.530306
# 13     HG   -2.595183
# 22     QR   25.771493
# 10     MC   -4.387476
# 5      CS   -2.556080
# 26     TC  -11.680469
# 2      BS    8.704222
# 3      CC   10.125671
# 15     MN   -3.674903
# 30     YN    3.771688
# 11     GT    4.469232
# 19     OC    1.239190
# 21     QO   -3.921002
# 20     PL   -1.535634

# %% [markdown]
# <div class="alert alert-success">
# Graficar los datos del parametro "Comparador" de los diferentes estados de México en un mapa
# </div>

# %%
#Cargar el archivo datos/geo/mexico_estados_geo en la variable estados_geo  
estados_geo = 'datos/geo/mexico_estados_geo.json'

# %%
# importar la libreria  folium
# Defina una referencia para graficar los paises
# location= [latitud,longitud]
# zoom_start=zoom donde comenzará
import folium
map = folium.Map(location=[24,-102], zoom_start=5)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04bcfcecf8ab1e31af54a9d0b9e66a21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04bcfcecf8ab1e31af54a9d0b9e66a21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04bcfcecf8ab1e31af54a9d0b9e66a21 = L.map(
#                 &quot;map_04bcfcecf8ab1e31af54a9d0b9e66a21&quot;,
#                 {
#                     center: [24.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc573cdf082443d4f5606cd69130711a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc573cdf082443d4f5606cd69130711a.addTo(map_04bcfcecf8ab1e31af54a9d0b9e66a21);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <div class="alert alert-warning">
# Opciones de la función Choropleth :
#
# <ul>
#   <li>geo_data=variable que guarda los datos JSON</li>
#   <li>data=DataFrame con los datos</li>
#   <li>key_on='feature.id'</li>
#   <li>fill_color=Estilo de colores</li>
#   <li>fill_opacity=Opacidad del relleno de 0 a 1 </li>
#   <li>line_opacity=Opacidad de la linea de 0 a 1</li>
#   <li>legend_name=titulo</li>
# </ul>
#
# </div>

# %%
map = folium.Map(location=[24,-102], zoom_start=5)

#TItulo
titulo="Comparacion de incremento porcentual de diabetes tipo 2 en 2017 y 2018"

folium.Choropleth(geo_data=estados_geo, data=df_IDC, 
             columns=['IDNAME', 'Comparador'],
             key_on='feature.id',
             fill_color='PRGn', fill_opacity=0.9, line_opacity=0.9, #YlGnBu
             legend_name=titulo).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66d042fa909d404a58402c9b1aa6f5ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66d042fa909d404a58402c9b1aa6f5ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66d042fa909d404a58402c9b1aa6f5ab = L.map(
#                 &quot;map_66d042fa909d404a58402c9b1aa6f5ab&quot;,
#                 {
#                     center: [24.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e015da6cbc464d278552fdb030600ac4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e015da6cbc464d278552fdb030600ac4.addTo(map_66d042fa909d404a58402c9b1aa6f5ab);
#
#
#             var choropleth_3559c79a51a3b4602da3488f715eae77 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_34579d41e17803957364e0458941a1ab_styler(feature) {
#             switch(feature.id) {
#                 case &quot;IS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;BC&quot;: case &quot;CH&quot;: case &quot;DG&quot;: case &quot;TS&quot;: case &quot;CC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0d3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;BS&quot;: case &quot;SR&quot;: case &quot;OC&quot;: case &quot;PL&quot;: case &quot;GT&quot;: case &quot;VZ&quot;: case &quot;YN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e7d4e8&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;CL&quot;: case &quot;SL&quot;: case &quot;ZS&quot;: case &quot;SP&quot;: case &quot;JC&quot;: case &quot;MN&quot;: case &quot;TC&quot;: case &quot;DF&quot;: case &quot;GR&quot;: case &quot;HG&quot;: case &quot;MC&quot;: case &quot;MS&quot;: case &quot;QO&quot;: case &quot;CS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#af8dc3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;AS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#762a83&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;CM&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1b7837&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fbf7b&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_34579d41e17803957364e0458941a1ab_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_34579d41e17803957364e0458941a1ab = L.geoJson(null, {
#                 onEachFeature: geo_json_34579d41e17803957364e0458941a1ab_onEachFeature,
#
#                 style: geo_json_34579d41e17803957364e0458941a1ab_styler,
#             ...{
# }
#         });
#
#         function geo_json_34579d41e17803957364e0458941a1ab_add (data) {
#             geo_json_34579d41e17803957364e0458941a1ab
#                 .addData(data);
#         }
#             geo_json_34579d41e17803957364e0458941a1ab_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-89.69261012599989, 22.56707303600014], [-89.62491973699994, 22.497943699000146], [-89.6101519099999, 22.461080928000015], [-89.63427615599994, 22.378891049000018], [-89.68458230099995, 22.380737837000154], [-89.69797173799986, 22.41754406200012], [-89.65516467999987, 22.47200127000012], [-89.6910718369999, 22.528628504000054], [-89.69261012599989, 22.56707303600014]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;IS&quot;, &quot;properties&quot;: {&quot;OBJECTID_1&quot;: 3622, &quot;abbrev&quot;: &quot;&quot;, &quot;adm0_a3&quot;: &quot;MEX&quot;, &quot;adm0_label&quot;: 2, &quot;adm0_sr&quot;: 6, &quot;adm1_cod_1&quot;: &quot;MEX+99?&quot;, &quot;adm1_code&quot;: &quot;MEX+99?&quot;, &quot;admin&quot;
