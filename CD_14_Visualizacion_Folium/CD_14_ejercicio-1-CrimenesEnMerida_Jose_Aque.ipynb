# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Ejericicio 1: Crimenes en la ciudad de Mérida (Ficticio)  </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/policia.jpeg" align="middle" style="width:550px"/></td>
# <td>
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head()
# Out:
#    NumInc  Categoria              Descripcion   Ciudad          Direccion  \
# 0       1     asalto  robo objetos personales  Tizimín             Centro
# 1       2     asalto  robo objetos personales   Mérida         Calle 53-F
# 2       3     asalto  robo objetos personales   Mérida   Calle 53 791-803
# 3       4     asalto  robo objetos personales   Mérida   Calle 49 808-796
# 4       5  robo casa     robo casa habitacion   Mérida  Calle 51A 784-780
#
#          lat       long
# 0  21.142586 -88.147633
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986
# 4  21.000559 -89.712173

# %%
len(data)
# Out:
# 28

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
for index, datos in data.iterrows():
    folium.Marker(location=[datos['lat'], datos['long']], popup=datos['Descripcion'], tooltip='<strong>' + datos['Categoria'].capitalize() + '</strong>', icon=folium.Icon(color='red', prefix='fa', icon='crosshairs')).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bf6ace33533f9a7050942e27e4608f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bf6ace33533f9a7050942e27e4608f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bf6ace33533f9a7050942e27e4608f4 = L.map(
#                 &quot;map_5bf6ace33533f9a7050942e27e4608f4&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89b2213c60c34217ff13db8749a68aef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89b2213c60c34217ff13db8749a68aef.addTo(map_5bf6ace33533f9a7050942e27e4608f4);
#
#
#             var marker_31266c37ca8b87578f1d00dbee773cc8 = L.marker(
#                 [21.142586, -88.147633],
#                 {
# }
#             ).addTo(map_5bf6ace33533f9a7050942e27e4608f4);
#
#
#             var icon_3729f5286b8bb8f586056f4f5e58cd4c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29e5dd2e16373af59d2dbc40d3d35c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bbad57806c4306bc727b1095570c2f5 = $(`&lt;div id=&quot;html_2bbad57806c4306bc727b1095570c2f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;robo objetos personales&lt;/div&gt;`)[0];
#                 popup_29e5dd2e16373af59d2dbc40d3d35c28.setContent(html_2bbad57806c4306bc727b1095570c2f5);
#
#
#
#         marker_31266c37ca8b87578f1d00dbee773cc8.bindPopup(popup_29e5dd2e16373af59d2dbc40d3d35c28)
#         ;
#
#
#
#
#             marker_31266c37ca8b87578f1d00dbee773cc8.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Asalto&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_31266c37ca8b87578f1d00dbee773cc8.setIcon(icon_3729f5286b8bb8f586056f4f5e58cd4c);
#
#
#             var marker_bdb8bcf6f1b0081eed47cfed70220da4 = L.marker(
#                 [21.074071, -89.666229],
#                 {
# }
#             ).addTo(map_5bf6ace33533f9a7050942e27e4608f4);
#
#
#             var icon_87bf14b151a4e4e6724b09933cee631f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cc27eba18156c3f7b46c98500f7c1c63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dfc6a73266bc7e715ce01b401feed0b = $(`&lt;div id=&quot;html_7dfc6a73266bc7e715ce01b401feed0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;robo objetos personales&lt;/div&gt;`)[0];
#                 popup_cc27eba18156c3f7b46c98500f7c1c63.setContent(html_7dfc6a73266bc7e715ce01b401feed0b);
#
#
#
#         marker_bdb8bcf6f1b0081eed47cfed70220da4.bindPopup(popup_cc27eba18156c3f7b46c98500f7c1c63)
#         ;
#
#
#
#
#             marker_bdb8bcf6f1b0081eed47cfed70220da4.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Asalto&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_bdb8bcf6f1b0081eed47cfed70220da4.setIcon(icon_87bf14b151a4e4e6724b09933cee631f);
#
#
#             var marker_a5e3901808690e0baaf6faf8ce2f2783 = L.marker(
#                 [21.07783, -89.655865],
#                 {
# }
#             ).addTo(map_5bf6ace33533f9a7050942e27e4608f4);
#
#
#             var icon_3f2f83b619893a0535cfef6e9d179c8c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;crosshairs&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b8dccfbfb78dbc9afa5a27c1e61c67ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2e2fac12389d2f315c0ec9e68f9176c = $(`&lt;div id=&quot;html_f2e2fac12389d2f315c0ec9e68f9
