# %% [markdown]
# <img align="left" style="padding-right:10px;" src="figuras/banner_cd.png">

# %% [markdown]
# # Proyecto de Machine Learning

# %% [markdown]
#
# En el mundo de las finanzas, la toma de decisiones relacionada con la aprobación de préstamos bancarios es fundamental para el éxito de las instituciones financieras y la seguridad de los clientes. Uno de los desafíos más cruciales en este contexto es la capacidad de prever con precisión si un individuo será capaz de cumplir con sus obligaciones de pago. Esta tarea adquiere una nueva dimensión en un entorno donde los datos masivos y las complejidades financieras requieren soluciones innovadoras.
#
# El presente proyecto se centra en abordar la problemática de determinar si un solicitante es apto para recibir un préstamo bancario basándose en 20 parámetros, (descritos a continuación). Se utilizarán distintos modelos de Machine Learning para determinar el de mejor desempeño

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0">Caso de estudio: German Credit Data </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
#
#
# <td><img src="figuras/deudor-intencional.jpg" align="middle" style="width:550px;"/></td>
# <td>
#
#
#
#
# Se proporcionan dos conjuntos de datos. El conjunto de datos original, en el formato proporcionado por el Prof. Hofmann, contiene atributos categóricos/simbólicos y se encuentra en el archivo "german.data".
#
# Para los algoritmos que necesitan atributos numéricos, la Universidad de Strathclyde produjo el archivo "german.data-numeric". Este archivo ha sido editado y se han agregado varias variables indicadoras para hacerlo adecuado para algoritmos que no pueden manejar variables categóricas. Varios atributos ordenados categóricamente (como el atributo 17) se han codificado como números enteros. Este fue el formulario utilizado por StatLog.
#
# [Statlog (German Credit Data)](https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data)
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# ## Descripción de los datos

# %% [markdown]
# A continuación se describe el significado de todos los parámetros utilizados en el presente proyecto. Se utilizó el archivo german.data, el cual contiene 13 atributos categóricos y 7 numéricos. El "target" o la variable que se quiere predecir se encuentra en el atributo 20, y se refiere a si un cliente es apto o no para otorgarle un préstamo.
#
# # Interpretación de los datos
#
# #### Attribute 1: Status of existing checking account
# - A11: ... < 0 DM
# - A12: 0 <= ... < 200 DM
# - A13: ... >= 200 DM / salary assignments for at least 1 year
# - A14: no checking account
#
# #### Attribute 2: Duration in month
# - Numerical
#
# #### Attribute 3: Credit history
# - A30: no credits taken/all credits paid back duly
# - A31: all credits at this bank paid back duly
# - A32: existing credits paid back duly till now
# - A33: delay in paying off in the past
# - A34: critical account/other credits existing (not at this bank)
#
# #### Attribute 4: Purpose
# - A40: car (new)
# - A41: car (used)
# - A42: furniture/equipment
# - A43: radio/television
# - A44: domestic appliances
# - A45: repairs
# - A46: education
# - A47: (vacation - does not exist?)
# - A48: retraining
# - A49: business
# - A410: others
#
# #### Attribute 5: Credit amount
# - Numerical
#
# #### Attribute 6: Savings account/bonds
# - A61: ... < 100 DM
# - A62: 100 <= ... < 500 DM
# - A63: 500 <= ... < 1000 DM
# - A64: ... >= 1000 DM
# - A65: unknown/no savings account
#
# #### Attribute 7: Present employment since
# - A71: unemployed
# - A72: ... < 1 year
# - A73: 1 <= ... < 4 years
# - A74: 4 <= ... < 7 years
# - A75: ... >= 7 years
#
# #### Attribute 8: Installment rate in percentage of disposable income
# - Numerical
#
# #### Attribute 9: Personal status and sex
# - A91: male: divorced/separated
# - A92: female: divorced/separated/married
# - A93: male: single
# - A94: male: married/widowed
# - A95: female: single
#
# #### Attribute 10: Other debtors/guarantors
# - A101: none
# - A102: co-applicant
# - A103: guarantor
#
# #### Attribute 11: Present residence since
# - Numerical
#
# #### Attribute 12: Property
# - A121: real estate
# - A122: if not A121: building society savings agreement/life insurance
# - A123: if not A121/A122: car or other, not in attribute 6
# - A124: unknown/no property
#
# #### Attribute 13: Age in years
# - Numerical
#
# #### Attribute 14: Other installment plans
# - A141: bank
# - A142: stores
# - A143: none
#
# #### Attribute 15: Housing
# - A151: rent
# - A152: own
# - A153: for free
#
# ###### Attribute 16: Number of existing credits at this bank
# - Numerical
#
# #### Attribute 17: Job
# - A171: unemployed/unskilled - non-resident
# - A172: unskilled - resident
# - A173: skilled employee/official
# - A174: management/self-employed/highly qualified employee/officer
#
# #### Attribute 18: Number of people being liable to provide maintenance for
# - Numerical
#
# #### Attribute 19: Telephone
# - A191: none
# - A192: 02: no
# nal status
# 1 : single
# 2 : married
# Personal status
# 1 : single
# 2 : married ars unt  bank)

# %% [markdown]
# ## 0. Librerias Generales

# %%
# Importar librerias
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Obtención y visualización de los datos

# %%
df = pd.read_csv('datos/train_val.csv')
df
# Out:
#       area  perimeter  compactness  kernel_length  kernel_width  \
# 0    10.82      12.83       0.8256          5.180         2.630
# 1    11.75      13.52       0.8082          5.444         2.678
# 2    10.83      12.96       0.8099          5.278         2.641
# 3    18.81      16.29       0.8906          6.272         3.693
# 4    17.32      15.91       0.8599          6.064         3.403
# ..     ...        ...          ...            ...           ...
# 160  20.16      17.03       0.8735          6.513         3.773
# 161  17.55      15.66       0.8991          5.791         3.690
# 162  12.36      13.19       0.8923          5.076         3.042
# 163  18.98      16.66       0.8590          6.549         3.670
# 164  19.38      16.72       0.8716          6.303         3.791
#
#      asymmetry_coefficient  kernel_groove_length     class
# 0                    4.853                 5.089  Canadian
# 1                    4.378                 5.310  Canadian
# 2                    5.182                 5.185  Canadian
# 3                    3.237                 6.053      Rosa
# 4                    3.824                 5.922      Rosa
# ..                     ...                   ...       ...
# 160                  1.910                 6.185      Rosa
# 161                  5.366                 5.661      Rosa
# 162                  3.220                 4.605      Kama
# 163                  3.691                 6.498      Rosa
# 164                  3.678                 5.965      Rosa
#
# [165 rows x 8 columns]

# %% [markdown]
# ## 2. Preparación de los datos y funciones

# %%
# Preparación de datos
from sklearn.model_selection import train_test_split

# %%
## Verificando que no existan valores nulos
df.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# #### División general de los datos
#
#
# * **X**: Datos sin el diagnostico es decir sin la columna "target"
# * **y**: Datos con el diagnostico es decir con la columna "target"
#
# Muestras de entrenamiento y prueba
# * **X_train**: este será el grupo de entrenamiento
# * **X_test**: este será el  grupo de prueba
# * **y_train**: este será el target para el grupo de entrenamiento
# * **y_test**: este será el target para el grupo de prueba

# %%
#Crear X (Quitar la columna o campo 24)
X =df.drop('class', axis=1)
X.head(2)
# Out:
#     area  perimeter  compactness  kernel_length  kernel_width  \
# 0  10.82      12.83       0.8256          5.180         2.630
# 1  11.75      13.52       0.8082          5.444         2.678
#
#    asymmetry_coefficient  kernel_groove_length
# 0                  4.853                 5.089
# 1                  4.378                 5.310

# %%
# Crear y (Valor de de la columna "target")
y=df['class']
y.head()
# Out:
# 0    Canadian
# 1    Canadian
# 2    Canadian
# 3        Rosa
# 4        Rosa
# Name: class, dtype: object

# %%
df
# Out:
#       area  perimeter  compactness  kernel_length  kernel_width  \
# 0    10.82      12.83       0.8256          5.180         2.630
# 1    11.75      13.52       0.8082          5.444         2.678
# 2    10.83      12.96       0.8099          5.278         2.641
# 3    18.81      16.29       0.8906          6.272         3.693
# 4    17.32      15.91       0.8599          6.064         3.403
# ..     ...        ...          ...            ...           ...
# 160  20.16      17.03       0.8735          6.513         3.773
# 161  17.55      15.66       0.8991          5.791         3.690
# 162  12.36      13.19       0.8923          5.076         3.042
# 163  18.98      16.66       0.8590          6.549         3.670
# 164  19.38      16.72       0.8716          6.303         3.791
#
#      asymmetry_coefficient  kernel_groove_length     class
# 0                    4.853                 5.089  Canadian
# 1                    4.378                 5.310  Canadian
# 2                    5.182                 5.185  Canadian
# 3                    3.237                 6.053      Rosa
# 4                    3.824                 5.922      Rosa
# ..                     ...                   ...       ...
# 160                  1.910                 6.185      Rosa
# 161                  5.366                 5.661      Rosa
# 162                  3.220                 4.605      Kama
# 163                  3.691                 6.498      Rosa
# 164                  3.678                 5.965      Rosa
#
# [165 rows x 8 columns]

# %%
# Dividir los datos para entrenamiento y prueba. Con un factor 80%
X_train , X_test, y_train, y_test = train_test_split(X, y, train_size=0.82, random_state=4)
print( 'X_train :' , X_train.shape )
print( 'X_test :' , X_test.shape )
print( 'y_train :' , y_train.shape )
print( 'y_test :' ,  y_test.shape )
print( 'df 100% :' ,  df.shape[0]   )
print( 'len(X_train) / 3 :' ,  len(X_train) / 3 )
# Out:
# X_train : (135, 7)
# X_test : (30, 7)
# y_train : (135,)
# y_test : (30,)
# df 100% : 165
# len(X_train) / 3 : 45.0

# %% [markdown]
# ### Pipeline

# %% [markdown]
# <img src="figuras/pipeline.jpg" align="middle" style="width:400px;" />

# %%
# Modulos importantes
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
# Mostrando columnas
df.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'kernel_length', 'kernel_width',
#        'asymmetry_coefficient', 'kernel_groove_length', 'class'],
#       dtype='object')

# %%
# Crear la lista de  viriables numericas  numeric_list 
numeric_list = [ 'area',  'compactness', 'kernel_length',
       'asymmetry_coefficient', 'kernel_groove_length' ]

# %%
# Crear el pipeline de preprocesamiento para datos numéricos  numeric_transformer
numeric_transformer = Pipeline(  steps = [ ('scaler',  StandardScaler()  )  ]   )

# %%
# Definir los transformadores
transformer = ColumnTransformer( [ ('num', numeric_transformer, numeric_list  )  ]  )

# %% [markdown]
# # 3. Implementación de Modelos

# %% [markdown]
# ## Tercer modelo: Random Forest

# %% [markdown]
# Referencias generales
# * https://www.learndatasci.com/glossary/binary-classification/
# * https://scikit-learn.org/stable/modules/grid_search.html
#
# Referencia RF
# * https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74

# %% [markdown]
# ## a) RF sin tunning

# %%
# Módulos del Modelo
#from sklearn.neural_network import MLPClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
# modelo 
from sklearn.ensemble import RandomForestClassifier

RF_Classifier =  RandomForestClassifier()

# %%
# Parametros del modelo DecisionTreeClassifier()
RF_Classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Definiendo el modelo_DT con su pipeline
modelo_RF = Pipeline(  [ ('transformer', transformer) , 
                        ('RF_Classifier',RF_Classifier)    ]  )

# %%
# Ajuste del modelo
modelo_RF.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['area', 'compactness',
#                                                    'kernel_length',
#                                                    'asymmetry_coefficient',
#                                                    'kernel_groove_length'])])),
#                 ('RF_Classifier', RandomForestClassifier())])

# %%
# Score sin tunning
modelo_RF.score(X_test, y_test)
# Out:
# 0.9

# %% [markdown]
# ## b) RF con tunning

# %%
# Definir los parametros con el diccionario params utilizando:


n_estimators= [10,15,20, 30, 50,100,150,200]
max_depth= [4,8,12 ]
min_samples_split= [2,6,8]
 

params = { 'RF_Classifier__n_estimators' : n_estimators,
         'RF_Classifier__max_depth': max_depth,
         'RF_Classifier__min_samples_split': min_samples_split }

# %%
# Ajuste de los parametros max_depth y min_samples_leaf con  GridSearchCV
from sklearn.model_selection import GridSearchCV

grid_RF = GridSearchCV(modelo_RF, 
                       param_grid= params,
                      cv=5,
                      n_jobs=-1,
                      verbose=10)

# %%
# Ajuste del modelo usando todas las posibles combinaciones de parámetros 
grid_RF.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 4/5; 1/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 4/5; 1/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 2/5; 1/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 4/5; 2/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 2/5; 1/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.852 total time=   0.1s
# [CV 4/5; 2/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.1s
# [CV 1/5; 2/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 5/5; 2/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 1/5; 2/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.1s
# [CV 5/5; 2/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.1s
# [CV 1/5; 3/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 5/5; 1/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 2/5; 3/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 1/5; 3/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.1s
# [CV 5/5; 1/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.1s
# [CV 2/5; 3/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 3/5; 3/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 1/5; 1/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 1/5; 1/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.0s
# [CV 3/5; 3/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=1.000 total time=   0.1s
# [CV 4/5; 3/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 4/5; 3/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.1s
# [CV 3/5; 1/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 5/5; 3/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 2/5; 2/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 3/5; 1/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 1/5; 4/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 2/5; 2/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.852 total time=   0.0s
# [CV 5/5; 3/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 2/5; 4/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 3/5; 2/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 3/5; 4/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 1/5; 4/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 4/5; 4/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 3/5; 2/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=1.000 total time=   0.1s
# [CV 2/5; 4/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 3/5; 4/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=1.000 total time=   0.1s
# [CV 5/5; 4/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 1/5; 5/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 4/5; 4/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.1s
# [CV 5/5; 4/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 2/5; 5/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 3/5; 5/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 1/5; 5/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.2s
# [CV 4/5; 5/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 2/5; 5/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.1s
# [CV 5/5; 5/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 1/5; 6/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 3/5; 5/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=1.000 total time=   0.2s
# [CV 4/5; 5/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.2s
# [CV 2/5; 6/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 3/5; 6/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 5/5; 5/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.852 total time=   0.2s
# [CV 4/5; 6/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 5/5; 6/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 1/5; 7/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 1/5; 6/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 2/5; 6/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.3s
# [CV 2/5; 7/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 3/5; 6/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.3s
# [CV 3/5; 7/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 4/5; 6/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.3s
# [CV 5/5; 6/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 4/5; 7/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 5/5; 7/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 1/5; 8/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 2/5; 8/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 1/5; 7/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 2/5; 7/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 3/5; 8/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 4/5; 8/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 3/5; 7/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 5/5; 8/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 1/5; 9/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 5/5; 7/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 1/5; 9/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.1s
# [CV 2/5; 9/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 4/5; 7/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.963 total time=   0.6s
# [CV 2/5; 9/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.1s
# [CV 3/5; 9/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 1/5; 8/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.6s
# [CV 4/5; 9/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 4/5; 9/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 3/5; 9/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.852 total time=   0.1s
# [CV 5/5; 9/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 2/5; 8/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.6s
# [CV 5/5; 9/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.889 total time=   0.0s
# [CV 1/5; 10/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 3/5; 8/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=1.000 total time=   0.6s
# [CV 2/5; 10/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 1/5; 10/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.852 total time=   0.1s
# [CV 3/5; 10/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 2/5; 10/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.1s
# [CV 4/5; 8/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.6s
# [CV 3/5; 10/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=1.000 total time=   0.0s
# [CV 4/5; 10/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 5/5; 10/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 5/5; 8/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.6s
# [CV 4/5; 10/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.0s
# [CV 1/5; 11/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 5/5; 10/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.0s
# [CV 2/5; 11/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 1/5; 11/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.0s
# [CV 3/5; 11/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 2/5; 11/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.1s
# [CV 4/5; 11/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 3/5; 11/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.0s
# [CV 5/5; 11/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 4/5; 11/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 1/5; 12/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 5/5; 11/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 2/5; 12/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 3/5; 12/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 1/5; 12/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.1s
# [CV 4/5; 12/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 2/5; 12/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 5/5; 12/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 3/5; 12/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.1s
# [CV 4/5; 12/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.1s
# [CV 1/5; 13/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 5/5; 12/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.1s
# [CV 2/5; 13/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 3/5; 13/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 4/5; 13/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 1/5; 13/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=0.852 total time=   0.1s
# [CV 5/5; 13/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 2/5; 13/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 1/5; 14/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 3/5; 13/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=1.000 total time=   0.1s
# [CV 4/5; 13/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 2/5; 14/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 5/5; 13/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 3/5; 14/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 4/5; 14/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 5/5; 14/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 1/5; 14/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 1/5; 15/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 2/5; 15/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 3/5; 14/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.3s
# [CV 2/5; 14/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 4/5; 14/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.3s
# [CV 3/5; 15/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 4/5; 15/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 5/5; 14/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 5/5; 15/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 1/5; 16/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 1/5; 15/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 2/5; 16/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 3/5; 16/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 2/5; 15/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 4/5; 16/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 3/5; 15/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 4/5; 15/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 5/5; 16/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 5/5; 15/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 1/5; 17/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 1/5; 17/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.889 total time=   0.1s
# [CV 2/5; 17/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 2/5; 17/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.1s
# [CV 3/5; 17/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 4/5; 17/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 3/5; 17/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=1.000 total time=   0.1s
# [CV 2/5; 16/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.6s
# [CV 1/5; 16/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.7s
# [CV 5/5; 17/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 4/5; 17/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.1s
# [CV 3/5; 16/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=1.000 total time=   0.5s
# [CV 5/5; 17/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.0s
# [CV 1/5; 18/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 1/5; 18/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.0s
# [CV 2/5; 18/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 4/5; 16/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.6s
# [CV 3/5; 18/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 2/5; 18/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.0s
# [CV 3/5; 18/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.0s
# [CV 4/5; 18/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 5/5; 16/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.5s
# [CV 5/5; 18/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 4/5; 18/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.0s
# [CV 1/5; 19/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 5/5; 18/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.1s
# [CV 2/5; 19/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 3/5; 19/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 1/5; 19/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 4/5; 19/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 3/5; 19/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 2/5; 19/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 5/5; 19/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 4/5; 19/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.1s
# [CV 1/5; 20/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 2/5; 20/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 5/5; 19/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.1s
# [CV 3/5; 20/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 1/5; 20/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.1s
# [CV 4/5; 20/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 2/5; 20/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.1s
# [CV 5/5; 20/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 4/5; 20/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.1s
# [CV 1/5; 21/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 3/5; 20/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=1.000 total time=   0.1s
# [CV 2/5; 21/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 5/5; 20/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 3/5; 21/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 1/5; 21/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 4/5; 21/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 2/5; 21/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.1s
# [CV 5/5; 21/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 1/5; 22/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 3/5; 21/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 2/5; 22/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 4/5; 21/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 3/5; 22/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 5/5; 21/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.1s
# [CV 4/5; 22/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 5/5; 22/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 1/5; 23/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 1/5; 22/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 2/5; 23/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 2/5; 22/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 3/5; 23/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 3/5; 22/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.3s
# [CV 4/5; 22/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.2s
# [CV 4/5; 23/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 5/5; 23/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 1/5; 24/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 5/5; 22/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 2/5; 24/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 3/5; 24/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 1/5; 23/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.5s
# [CV 2/5; 23/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 4/5; 24/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 3/5; 23/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 4/5; 23/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.963 total time=   0.4s
# [CV 5/5; 24/72] START RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 1/5; 25/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 1/5; 25/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.1s
# [CV 5/5; 23/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.5s
# [CV 2/5; 25/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 3/5; 25/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 2/5; 25/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.889 total time=   0.1s
# [CV 1/5; 24/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.6s
# [CV 4/5; 25/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 3/5; 25/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=1.000 total time=   0.1s
# [CV 4/5; 25/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 2/5; 24/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.6s
# [CV 5/5; 25/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10
# [CV 5/5; 25/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=10;, score=0.815 total time=   0.0s
# [CV 1/5; 26/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 3/5; 24/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=1.000 total time=   0.6s
# [CV 2/5; 26/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 4/5; 24/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.5s
# [CV 1/5; 26/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.1s
# [CV 3/5; 26/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 5/5; 24/72] END RF_Classifier__max_depth=4, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.5s
# [CV 2/5; 26/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.0s
# [CV 4/5; 26/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 3/5; 26/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.0s
# [CV 5/5; 26/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15
# [CV 4/5; 26/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.0s
# [CV 1/5; 27/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 5/5; 26/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.0s
# [CV 2/5; 27/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 1/5; 27/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 3/5; 27/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 4/5; 27/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 2/5; 27/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.0s
# [CV 5/5; 27/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20
# [CV 4/5; 27/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 3/5; 27/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.1s
# [CV 1/5; 28/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 5/5; 27/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 2/5; 28/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 1/5; 28/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 3/5; 28/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 2/5; 28/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.852 total time=   0.1s
# [CV 4/5; 28/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 5/5; 28/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30
# [CV 3/5; 28/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.1s
# [CV 1/5; 29/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 4/5; 28/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 5/5; 28/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=30;, score=0.852 total time=   0.1s
# [CV 2/5; 29/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 3/5; 29/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 1/5; 29/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 4/5; 29/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 5/5; 29/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50
# [CV 2/5; 29/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 1/5; 30/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 3/5; 29/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=1.000 total time=   0.1s
# [CV 2/5; 30/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 4/5; 29/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 3/5; 30/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 5/5; 29/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 4/5; 30/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 5/5; 30/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100
# [CV 1/5; 31/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 1/5; 30/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 2/5; 30/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 2/5; 31/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 3/5; 31/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 3/5; 30/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5; 31/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 4/5; 30/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.2s
# [CV 5/5; 31/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150
# [CV 1/5; 32/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 5/5; 30/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.3s
# [CV 2/5; 32/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 3/5; 32/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 1/5; 31/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 2/5; 31/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 4/5; 32/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 3/5; 31/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 5/5; 32/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200
# [CV 4/5; 31/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.963 total time=   0.4s
# [CV 1/5; 33/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 5/5; 31/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 1/5; 33/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.852 total time=   0.0s
# [CV 2/5; 33/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 2/5; 33/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 3/5; 33/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 3/5; 33/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=1.000 total time=   0.0s
# [CV 4/5; 33/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 4/5; 33/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.0s
# [CV 5/5; 33/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10
# [CV 5/5; 33/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=10;, score=0.778 total time=   0.0s
# [CV 1/5; 34/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 1/5; 32/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.6s
# [CV 3/5; 32/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=1.000 total time=   0.5s
# [CV 2/5; 34/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 1/5; 34/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.0s
# [CV 2/5; 32/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.6s
# [CV 3/5; 34/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 2/5; 34/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.1s
# [CV 4/5; 34/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 3/5; 34/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=1.000 total time=   0.1s
# [CV 4/5; 32/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.5s
# [CV 5/5; 34/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15
# [CV 4/5; 34/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.963 total time=   0.1s
# [CV 1/5; 35/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 5/5; 34/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.1s
# [CV 5/5; 32/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=2, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.5s
# [CV 2/5; 35/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 1/5; 35/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.1s
# [CV 2/5; 35/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.0s
# [CV 3/5; 35/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 4/5; 35/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 3/5; 35/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=1.000 total time=   0.0s
# [CV 5/5; 35/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20
# [CV 1/5; 36/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 4/5; 35/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.1s
# [CV 5/5; 35/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 2/5; 36/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 3/5; 36/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 1/5; 36/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 4/5; 36/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 2/5; 36/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 5/5; 36/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30
# [CV 3/5; 36/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=1.000 total time=   0.1s
# [CV 1/5; 37/72] START RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50
# [CV 5/5; 36/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# [CV 4/5; 36/72] END RF_Classifier__max_depth=8, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.1s
# ...
# [CV 5/5; 61/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.1s
# [CV 3/5; 62/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 4/5; 62/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 5/5; 62/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100
# [CV 1/5; 63/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 2/5; 63/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 1/5; 62/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 2/5; 62/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.889 total time=   0.2s
# [CV 3/5; 63/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 4/5; 63/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 3/5; 62/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5; 62/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.2s
# [CV 5/5; 63/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150
# [CV 5/5; 62/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.2s
# [CV 1/5; 64/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 2/5; 64/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 3/5; 64/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 1/5; 63/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.3s
# [CV 4/5; 64/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 2/5; 63/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 5/5; 64/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200
# [CV 3/5; 63/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 4/5; 63/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.963 total time=   0.3s
# [CV 1/5; 65/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 1/5; 65/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.852 total time=   0.0s
# [CV 5/5; 63/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 2/5; 65/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 2/5; 65/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.889 total time=   0.0s
# [CV 3/5; 65/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 4/5; 65/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 3/5; 65/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.963 total time=   0.0s
# [CV 2/5; 64/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.4s
# [CV 4/5; 65/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.926 total time=   0.0s
# [CV 5/5; 65/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10
# [CV 1/5; 64/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.5s
# [CV 1/5; 66/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 5/5; 65/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=10;, score=0.852 total time=   0.0s
# [CV 2/5; 66/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 1/5; 66/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.0s
# [CV 3/5; 66/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 3/5; 64/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=1.000 total time=   0.5s
# [CV 2/5; 66/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.889 total time=   0.0s
# [CV 4/5; 66/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 3/5; 66/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=1.000 total time=   0.0s
# [CV 5/5; 66/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15
# [CV 4/5; 64/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.5s
# [CV 1/5; 67/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 4/5; 66/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.0s
# [CV 5/5; 66/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=15;, score=0.926 total time=   0.0s
# [CV 2/5; 67/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 1/5; 67/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.852 total time=   0.0s
# [CV 5/5; 64/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=6, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.5s
# [CV 2/5; 67/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.889 total time=   0.0s
# [CV 3/5; 67/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 4/5; 67/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 5/5; 67/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20
# [CV 3/5; 67/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 1/5; 68/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 4/5; 67/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.963 total time=   0.0s
# [CV 5/5; 67/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=20;, score=0.926 total time=   0.0s
# [CV 2/5; 68/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 3/5; 68/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 1/5; 68/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.1s
# [CV 2/5; 68/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.889 total time=   0.0s
# [CV 4/5; 68/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 3/5; 68/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.0s
# [CV 5/5; 68/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30
# [CV 1/5; 69/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 4/5; 68/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.963 total time=   0.8s
# [CV 2/5; 69/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 5/5; 68/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=30;, score=0.926 total time=   0.8s
# [CV 3/5; 69/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 1/5; 69/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.8s
# [CV 4/5; 69/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 3/5; 69/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 5/5; 69/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50
# [CV 2/5; 69/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.926 total time=   0.1s
# [CV 1/5; 70/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 4/5; 69/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.963 total time=   0.1s
# [CV 2/5; 70/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 5/5; 69/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=50;, score=0.889 total time=   0.1s
# [CV 3/5; 70/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 4/5; 70/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 5/5; 70/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100
# [CV 1/5; 70/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.2s
# [CV 1/5; 71/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 2/5; 71/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 3/5; 71/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 3/5; 70/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5; 71/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 2/5; 70/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.2s
# [CV 5/5; 71/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150
# [CV 5/5; 70/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.926 total time=   0.2s
# [CV 1/5; 72/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 4/5; 70/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=100;, score=0.963 total time=   0.2s
# [CV 2/5; 72/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 3/5; 72/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 1/5; 71/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.889 total time=   0.4s
# [CV 4/5; 72/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 3/5; 71/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=1.000 total time=   0.4s
# [CV 2/5; 71/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 5/5; 72/72] START RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200
# [CV 4/5; 71/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.963 total time=   0.4s
# [CV 5/5; 71/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=150;, score=0.926 total time=   0.4s
# [CV 1/5; 72/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.889 total time=   0.4s
# [CV 2/5; 72/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.4s
# [CV 3/5; 72/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.5s
# [CV 5/5; 72/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.926 total time=   0.3s
# [CV 4/5; 72/72] END RF_Classifier__max_depth=12, RF_Classifier__min_samples_split=8, RF_Classifier__n_estimators=200;, score=0.963 total time=   0.4s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['area',
#                                                                           'compactness',
#                                                                           'kernel_length',
#                                                                           'asymmetry_coefficient',
#                                                                           'kernel_groove_length'])])),
#                                        ('RF_Classifier',
#                                         RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'RF_Classifier__max_depth': [4, 8, 12],
#                          'RF_Classifier__min_samples_split': [2, 6, 8],
#                          'RF_Classifier__n_estimators': [10, 15, 20, 30, 50,
#                                                          100, 150, 200]},
#              verbose=10)

# %%
#Encontrar los mejores parametros con best_params_
grid_RF.best_params_
# Out:
# {'RF_Classifier__max_depth': 4,
#  'RF_Classifier__min_samples_split': 2,
#  'RF_Classifier__n_estimators': 30}

# %%
# Ajustar el modelo con los nuevos parámetros  
RF_Classifier_tunned =  RandomForestClassifier(max_depth= 4, min_samples_split =2 , n_estimators = 30 )

# %%
# Definiendo el modelo_DT con su pipeline
modelo_RF_tunned = Pipeline(  [ ('transformer', transformer) , 
                        ('RF_Classifier_tunned',RF_Classifier_tunned)    ]  )

# %%
#  Ajustar el modelo
modelo_RF_tunned.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['area', 'compactness',
#                                                    'kernel_length',
#                                                    'asymmetry_coefficient',
#                                                    'kernel_groove_length'])])),
#                 ('RF_Classifier_tunned',
#                  RandomForestClassifier(max_depth=4, n_estimators=30))])

# %%
# Predicción
y_predict = modelo_RF_tunned.predict(X_test)
y_predict
# Out:
# array(['Rosa', 'Kama', 'Kama', 'Kama', 'Kama', 'Canadian', 'Kama', 'Kama',
#        'Kama', 'Rosa', 'Kama', 'Canadian', 'Canadian', 'Kama', 'Kama',
#        'Rosa', 'Canadian', 'Rosa', 'Canadian', 'Canadian', 'Kama', 'Rosa',
#        'Kama', 'Canadian', 'Rosa', 'Canadian', 'Rosa', 'Kama', 'Rosa',
#        'Canadian'], dtype=object)

# %%
# Prueba en y_test
y_test.values
# Out:
# array(['Rosa', 'Kama', 'Kama', 'Kama', 'Canadian', 'Canadian', 'Kama',
#        'Kama', 'Rosa', 'Rosa', 'Kama', 'Canadian', 'Canadian', 'Kama',
#        'Kama', 'Rosa', 'Canadian', 'Rosa', 'Canadian', 'Canadian', 'Kama',
#        'Rosa', 'Kama', 'Canadian', 'Rosa', 'Kama', 'Rosa', 'Kama', 'Rosa',
#        'Canadian'], dtype=object)

# %%
# Comparación
#np.equal(  y_predict , y_test.values )

# %%
# Score
np.equal(  y_predict , y_test.values  ).sum()/ len(y_predict)
# Out:
# np.float64(0.9)

# %%
# Score
modelo_RF_tunned.score(X_test, y_test)
# Out:
# 0.9

# %% [markdown]
# ### Guardar el modelo entrenado

# %%
import joblib

# %%
#Exportar el modelo
#joblib.dump(modelo, 'Ubicación del archivo .joblib')
joblib.dump(modelo_RF_tunned, 'modelos/modelo_RF_tunned_Semilla.joblib')
# Out:
# ['modelos/modelo_RF_tunned_Semilla.joblib']

# %%
# Importar librerias
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions_DT_tunned = modelo_RF_tunned.predict(X_test)
cm_DT_tunned = confusion_matrix(y_test, predictions_DT_tunned, labels=modelo_RF_tunned.classes_)
disp_DT_tunned  = ConfusionMatrixDisplay(confusion_matrix=cm_DT_tunned, display_labels=modelo_RF_tunned.classes_)
disp_DT_tunned.plot()
plt.title('Random Forest')
plt.show()
