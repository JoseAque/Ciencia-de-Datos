# %% [markdown]
# <img align="left" style="padding-right:10px;" src="figuras/banner_cd.png">

# %% [markdown]
# # Proyecto de Machine Learning

# %% [markdown]
#
# En el mundo de las finanzas, la toma de decisiones relacionada con la aprobación de préstamos bancarios es fundamental para el éxito de las instituciones financieras y la seguridad de los clientes. Uno de los desafíos más cruciales en este contexto es la capacidad de prever con precisión si un individuo será capaz de cumplir con sus obligaciones de pago. Esta tarea adquiere una nueva dimensión en un entorno donde los datos masivos y las complejidades financieras requieren soluciones innovadoras.
#
# El presente proyecto se centra en abordar la problemática de determinar si un solicitante es apto para recibir un préstamo bancario basándose en 20 parámetros, (descritos a continuación). Se utilizarán distintos modelos de Machine Learning para determinar el de mejor desempeño

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0">Caso de estudio: German Credit Data </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
#
#
# <td><img src="figuras/deudor-intencional.jpg" align="middle" style="width:550px;"/></td>
# <td>
#
#
#
#
# Se proporcionan dos conjuntos de datos. El conjunto de datos original, en el formato proporcionado por el Prof. Hofmann, contiene atributos categóricos/simbólicos y se encuentra en el archivo "german.data".
#
# Para los algoritmos que necesitan atributos numéricos, la Universidad de Strathclyde produjo el archivo "german.data-numeric". Este archivo ha sido editado y se han agregado varias variables indicadoras para hacerlo adecuado para algoritmos que no pueden manejar variables categóricas. Varios atributos ordenados categóricamente (como el atributo 17) se han codificado como números enteros. Este fue el formulario utilizado por StatLog.
#
# [Statlog (German Credit Data)](https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data)
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# ## Descripción de los datos

# %% [markdown]
# A continuación se describe el significado de todos los parámetros utilizados en el presente proyecto. Se utilizó el archivo german.data, el cual contiene 13 atributos categóricos y 7 numéricos. El "target" o la variable que se quiere predecir se encuentra en el atributo 20, y se refiere a si un cliente es apto o no para otorgarle un préstamo.
#
# # Interpretación de los datos
#
# #### Attribute 1: Status of existing checking account
# - A11: ... < 0 DM
# - A12: 0 <= ... < 200 DM
# - A13: ... >= 200 DM / salary assignments for at least 1 year
# - A14: no checking account
#
# #### Attribute 2: Duration in month
# - Numerical
#
# #### Attribute 3: Credit history
# - A30: no credits taken/all credits paid back duly
# - A31: all credits at this bank paid back duly
# - A32: existing credits paid back duly till now
# - A33: delay in paying off in the past
# - A34: critical account/other credits existing (not at this bank)
#
# #### Attribute 4: Purpose
# - A40: car (new)
# - A41: car (used)
# - A42: furniture/equipment
# - A43: radio/television
# - A44: domestic appliances
# - A45: repairs
# - A46: education
# - A47: (vacation - does not exist?)
# - A48: retraining
# - A49: business
# - A410: others
#
# #### Attribute 5: Credit amount
# - Numerical
#
# #### Attribute 6: Savings account/bonds
# - A61: ... < 100 DM
# - A62: 100 <= ... < 500 DM
# - A63: 500 <= ... < 1000 DM
# - A64: ... >= 1000 DM
# - A65: unknown/no savings account
#
# #### Attribute 7: Present employment since
# - A71: unemployed
# - A72: ... < 1 year
# - A73: 1 <= ... < 4 years
# - A74: 4 <= ... < 7 years
# - A75: ... >= 7 years
#
# #### Attribute 8: Installment rate in percentage of disposable income
# - Numerical
#
# #### Attribute 9: Personal status and sex
# - A91: male: divorced/separated
# - A92: female: divorced/separated/married
# - A93: male: single
# - A94: male: married/widowed
# - A95: female: single
#
# #### Attribute 10: Other debtors/guarantors
# - A101: none
# - A102: co-applicant
# - A103: guarantor
#
# #### Attribute 11: Present residence since
# - Numerical
#
# #### Attribute 12: Property
# - A121: real estate
# - A122: if not A121: building society savings agreement/life insurance
# - A123: if not A121/A122: car or other, not in attribute 6
# - A124: unknown/no property
#
# #### Attribute 13: Age in years
# - Numerical
#
# #### Attribute 14: Other installment plans
# - A141: bank
# - A142: stores
# - A143: none
#
# #### Attribute 15: Housing
# - A151: rent
# - A152: own
# - A153: for free
#
# ###### Attribute 16: Number of existing credits at this bank
# - Numerical
#
# #### Attribute 17: Job
# - A171: unemployed/unskilled - non-resident
# - A172: unskilled - resident
# - A173: skilled employee/official
# - A174: management/self-employed/highly qualified employee/officer
#
# #### Attribute 18: Number of people being liable to provide maintenance for
# - Numerical
#
# #### Attribute 19: Telephone
# - A191: none
# - A192: 02: no
# nal status
# 1 : single
# 2 : married
# Personal status
# 1 : single
# 2 : married ars unt  bank)

# %% [markdown]
# ## 0. Librerias Generales

# %%
# Importar librerias
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Obtención y visualización de los datos

# %%
#Cargar el archivo datos/german_train_test.txt
df = pd.read_csv('datos/train_val.csv')
df
# Out:
#       area  perimeter  compactness  kernel_length  kernel_width  \
# 0    10.82      12.83       0.8256          5.180         2.630
# 1    11.75      13.52       0.8082          5.444         2.678
# 2    10.83      12.96       0.8099          5.278         2.641
# 3    18.81      16.29       0.8906          6.272         3.693
# 4    17.32      15.91       0.8599          6.064         3.403
# ..     ...        ...          ...            ...           ...
# 160  20.16      17.03       0.8735          6.513         3.773
# 161  17.55      15.66       0.8991          5.791         3.690
# 162  12.36      13.19       0.8923          5.076         3.042
# 163  18.98      16.66       0.8590          6.549         3.670
# 164  19.38      16.72       0.8716          6.303         3.791
#
#      asymmetry_coefficient  kernel_groove_length     class
# 0                    4.853                 5.089  Canadian
# 1                    4.378                 5.310  Canadian
# 2                    5.182                 5.185  Canadian
# 3                    3.237                 6.053      Rosa
# 4                    3.824                 5.922      Rosa
# ..                     ...                   ...       ...
# 160                  1.910                 6.185      Rosa
# 161                  5.366                 5.661      Rosa
# 162                  3.220                 4.605      Kama
# 163                  3.691                 6.498      Rosa
# 164                  3.678                 5.965      Rosa
#
# [165 rows x 8 columns]

# %% [markdown]
# ## 2. Preparación de los datos y funciones

# %%
# Preparación de datos
from sklearn.model_selection import train_test_split

# %%
df.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# #### División general de los datos
#
#
# * **X**: Datos sin el diagnostico es decir sin la columna "target"
# * **y**: Datos con el diagnostico es decir con la columna "target"
#
# Muestras de entrenamiento y prueba
# * **X_train**: este será el grupo de entrenamiento
# * **X_test**: este será el  grupo de prueba
# * **y_train**: este será el target para el grupo de entrenamiento
# * **y_test**: este será el target para el grupo de prueba

# %%
#Crear X (Quitar la columna o campo 24)
X =df.drop('class', axis=1)
X.head(2)
# Out:
#     area  perimeter  compactness  kernel_length  kernel_width  \
# 0  10.82      12.83       0.8256          5.180         2.630
# 1  11.75      13.52       0.8082          5.444         2.678
#
#    asymmetry_coefficient  kernel_groove_length
# 0                  4.853                 5.089
# 1                  4.378                 5.310

# %%
# Crear y (Valor de de la columna "target")
y=df['class']
y.head()
# Out:
# 0    Canadian
# 1    Canadian
# 2    Canadian
# 3        Rosa
# 4        Rosa
# Name: class, dtype: object

# %%
df
# Out:
#       area  perimeter  compactness  kernel_length  kernel_width  \
# 0    10.82      12.83       0.8256          5.180         2.630
# 1    11.75      13.52       0.8082          5.444         2.678
# 2    10.83      12.96       0.8099          5.278         2.641
# 3    18.81      16.29       0.8906          6.272         3.693
# 4    17.32      15.91       0.8599          6.064         3.403
# ..     ...        ...          ...            ...           ...
# 160  20.16      17.03       0.8735          6.513         3.773
# 161  17.55      15.66       0.8991          5.791         3.690
# 162  12.36      13.19       0.8923          5.076         3.042
# 163  18.98      16.66       0.8590          6.549         3.670
# 164  19.38      16.72       0.8716          6.303         3.791
#
#      asymmetry_coefficient  kernel_groove_length     class
# 0                    4.853                 5.089  Canadian
# 1                    4.378                 5.310  Canadian
# 2                    5.182                 5.185  Canadian
# 3                    3.237                 6.053      Rosa
# 4                    3.824                 5.922      Rosa
# ..                     ...                   ...       ...
# 160                  1.910                 6.185      Rosa
# 161                  5.366                 5.661      Rosa
# 162                  3.220                 4.605      Kama
# 163                  3.691                 6.498      Rosa
# 164                  3.678                 5.965      Rosa
#
# [165 rows x 8 columns]

# %%
# Dividir los datos para entrenamiento y prueba. Con un factor 80%
X_train , X_test, y_train, y_test = train_test_split(X, y, train_size=0.82, random_state=42)
print( 'X_train :' , X_train.shape )
print( 'X_test :' , X_test.shape )
print( 'y_train :' , y_train.shape )
print( 'y_test :' ,  y_test.shape )
print( 'df 100% :' ,  df.shape[0]   )
print( 'len(X_train) / 3 :' ,  len(X_train) / 3 )
# Out:
# X_train : (135, 7)
# X_test : (30, 7)
# y_train : (135,)
# y_test : (30,)
# df 100% : 165
# len(X_train) / 3 : 45.0

# %% [markdown]
# ### Pipeline

# %% [markdown]
# <img src="figuras/pipeline.jpg" align="middle" style="width:400px;" />

# %%
# Modulos importantes
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
# Mostrando columnas
df.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'kernel_length', 'kernel_width',
#        'asymmetry_coefficient', 'kernel_groove_length', 'class'],
#       dtype='object')

# %%
# Crear la lista de  viriables numericas  numeric_list 
numeric_list = [ 'area',  'compactness', 'kernel_length',
       'asymmetry_coefficient', 'kernel_groove_length' ]

# %%
# Crear el pipeline de preprocesamiento para datos numéricos  numeric_transformer
numeric_transformer = Pipeline(  steps = [ ('scaler',  StandardScaler()  )  ]   )

# %%
# Definir los transformadores
transformer = ColumnTransformer( [ ('num', numeric_transformer, numeric_list  )  ]  )

# %% [markdown]
# # 3. Implementación de Modelos

# %% [markdown]
# ## Segundo modelo: Multi Layer Perceptron (MLP)

# %% [markdown]
# Referencia
# * https://michael-fuchs-python.netlify.app/2021/02/03/nn-multi-layer-perceptron-classifier-mlpclassifier/

# %% [markdown]
# ## a) MLP sin tunning

# %%
# Módulos del Modelo
from sklearn.neural_network import MLPClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
# modelo DecisionTreeClassifier llamado DT_Classifier
MLP_Classifier = MLPClassifier(max_iter = 1000)

# %%
# Parametros del modelo DecisionTreeClassifier()
MLP_Classifier.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 1000,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
# Definiendo el modelo_DT con su pipeline
modelo_MLP = Pipeline(  [ ('transformer', transformer) , 
                        ('MLP_Classifier',MLP_Classifier)    ]  )

# %%
# Ajuste del modelo
modelo_MLP.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['area', 'compactness',
#                                                    'kernel_length',
#                                                    'asymmetry_coefficient',
#                                                    'kernel_groove_length'])])),
#                 ('MLP_Classifier', MLPClassifier(max_iter=1000))])

# %%
# Score sin tunning
modelo_MLP.score(X_test, y_test)
# Out:
# 0.9

# %% [markdown]
# ## b) MLP con tunning

# %%
# Definir los parametros con el diccionario params utilizando:
hidden_layer_sizes= [(150,100,50), (120,80,40), (100,50,30)]
max_iter= [ 500 ]
activation= ['tanh', 'relu']
solver= ['sgd']
alpha= [0.0001, 0.05]

params = { 'MLP_Classifier__hidden_layer_sizes' : hidden_layer_sizes,
         'MLP_Classifier__max_iter': max_iter,
         'MLP_Classifier__activation': activation ,
         'MLP_Classifier__solver': solver ,
         'MLP_Classifier__alpha': alpha }

# %%
# Ajuste de los parametros max_depth y min_samples_leaf con  GridSearchCV
from sklearn.model_selection import GridSearchCV

grid_MLP = GridSearchCV(modelo_MLP, 
                       param_grid= params,
                      cv=5,
                      n_jobs=-1,
                      verbose=10)

# %%
# Ajuste del modelo usando todas las posibles combinaciones de parametros 
grid_MLP.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 3/5; 1/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 1/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 1/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 1/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 2/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 2/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 2/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 1/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5; 2/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.2s
# [CV 3/5; 2/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.926 total time=   1.3s
# [CV 4/5; 2/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 2/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 1/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.852 total time=   1.6s
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 2/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.4s
# [CV 1/5; 1/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.7s
# [CV 1/5; 3/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 1/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.7s
# [CV 2/5; 3/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 3/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 3/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 1/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   1.4s
# [CV 5/5; 1/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.8s
# [CV 5/5; 3/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 4/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 3/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   0.9s
# [CV 2/5; 4/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 2/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   1.2s
# [CV 3/5; 4/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 3/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   0.9s
# [CV 4/5; 4/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 3/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.0s
# [CV 5/5; 4/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 3/5; 3/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.926 total time=   1.2s
# [CV 1/5; 5/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 2/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.5s
# [CV 2/5; 5/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 3/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 3/5; 5/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 4/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.8s
# [CV 4/5; 5/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 5/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 5/5; 5/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 4/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   1.5s
# [CV 1/5; 6/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5; 4/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.7s
# [CV 2/5; 6/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 5/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.852 total time=   1.3s
# [CV 3/5; 6/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 4/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.852 total time=   1.7s
# [CV 4/5; 6/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 5/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.4s
# [CV 5/5; 6/12] START MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5; 4/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.9s
# [CV 1/5; 7/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 5/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   1.2s
# [CV 2/5; 7/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5; 6/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   0.8s
# [CV 5/5; 5/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 3/5; 7/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 6/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   0.9s
# [CV 4/5; 7/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 7/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 6/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 1/5; 8/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 3/5; 6/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.852 total time=   1.2s
# [CV 2/5; 8/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 6/12] END MLP_Classifier__activation=tanh, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 3/5; 8/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 7/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.4s
# [CV 4/5; 8/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5; 7/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.7s
# [CV 5/5; 8/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 8/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.4s
# [CV 1/5; 9/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 7/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.889 total time=   1.6s
# [CV 2/5; 9/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 7/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   1.6s
# [CV 3/5; 9/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5; 8/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.4s
# [CV 4/5; 9/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 8/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.889 total time=   1.4s
# [CV 5/5; 9/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 8/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.778 total time=   1.2s
# [CV 1/5; 10/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5; 7/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.9s
# [CV 2/5; 10/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5; 9/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   0.9s
# [CV 3/5; 10/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5; 8/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.2s
# [CV 4/5; 10/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 9/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.889 total time=   1.1s
# [CV 5/5; 10/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 9/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.2s
# [CV 1/5; 11/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5; 9/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 2/5; 11/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 4/5; 9/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.0001, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   1.2s
# [CV 3/5; 11/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5; 10/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.6s
# [CV 4/5; 11/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 10/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.6s
# [CV 5/5; 11/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 3/5; 10/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.889 total time=   1.5s
# [CV 1/5; 12/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 1/5; 11/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.1s
# [CV 2/5; 12/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5; 10/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   1.5s
# [CV 5/5; 10/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(150, 100, 50), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.4s
# [CV 3/5; 12/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 2/5; 11/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   1.3s
# [CV 4/5; 12/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 5/5; 12/12] START MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd
# [CV 3/5; 11/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.852 total time=   1.3s
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5; 11/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   1.0s
# [CV 2/5; 12/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.963 total time=   0.7s
# [CV 1/5; 12/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   0.8s
# [CV 5/5; 12/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   0.6s
# [CV 5/5; 11/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(120, 80, 40), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=1.000 total time=   1.2s
# [CV 3/5; 12/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.889 total time=   0.6s
# /home/yosake/.pyenv/versions/3.10.11/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5; 12/12] END MLP_Classifier__activation=relu, MLP_Classifier__alpha=0.05, MLP_Classifier__hidden_layer_sizes=(100, 50, 30), MLP_Classifier__max_iter=500, MLP_Classifier__solver=sgd;, score=0.815 total time=   0.7s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['area',
#                                                                           'compactness',
#                                                                           'kernel_length',
#                                                                           'asymmetry_coefficient',
#                                                                           'kernel_groove_length'])])),
#                                        ('MLP_Classifier',
#                                         MLPClassifier(max_iter=1000))]),
#              n_jobs=-1,
#              param_grid={'MLP_Classifier__activation': ['tanh', 'relu'],
#                          'MLP_Classifier__alpha': [0.0001, 0.05],
#                          'MLP_Classifier__hidden_layer_sizes': [(150, 100, 50),
#                                                                 (120, 80, 40),
#                                                                 (100, 50, 30)],
#                          'MLP_Classifier__max_iter': [500],
#                          'MLP_Classifier__solver': ['sgd']},
#              verbose=10)

# %%
#Encontrar los mejores parametros con best_params_
grid_MLP.best_params_
# Out:
# {'MLP_Classifier__activation': 'tanh',
#  'MLP_Classifier__alpha': 0.0001,
#  'MLP_Classifier__hidden_layer_sizes': (120, 80, 40),
#  'MLP_Classifier__max_iter': 500,
#  'MLP_Classifier__solver': 'sgd'}

# %%
# Ajustar el modelo con los nuevos parametros nombrandolo como  DT_Classifier_tunned
MLP_Classifier_tunned =  MLPClassifier(activation='tanh',
                                              alpha=0.0001 , 
                                                hidden_layer_sizes=(120, 80, 40),
                                               max_iter=500,
                                               solver='sgd')

# %%
# Definiendo el modelo_DT con su pipeline
modelo_MLP_tunned = Pipeline(  [ ('transformer', transformer) , 
                        ('MLP_Classifier_tunned',MLP_Classifier_tunned)    ]  )

# %%
#  Ajustar el modelo
modelo_MLP_tunned.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['area', 'compactness',
#                                                    'kernel_length',
#                                                    'asymmetry_coefficient',
#                                                    'kernel_groove_length'])])),
#                 ('MLP_Classifier_tunned',
#                  MLPClassifier(activation='tanh',
#                                hidden_layer_sizes=(120, 80, 40), max_iter=500,
#                                solver='sgd'))])

# %%
# Predicción
y_predict = modelo_MLP_tunned.predict(X_test)
y_predict
# Out:
# array(['Rosa', 'Canadian', 'Canadian', 'Kama', 'Kama', 'Kama', 'Canadian',
#        'Kama', 'Kama', 'Kama', 'Kama', 'Rosa', 'Kama', 'Kama', 'Canadian',
#        'Canadian', 'Canadian', 'Kama', 'Rosa', 'Canadian', 'Kama',
#        'Canadian', 'Kama', 'Canadian', 'Rosa', 'Rosa', 'Rosa', 'Rosa',
#        'Kama', 'Rosa'], dtype='<U8')

# %%
# Prueba en y_test
y_test.values
# Out:
# array(['Rosa', 'Canadian', 'Canadian', 'Kama', 'Canadian', 'Canadian',
#        'Canadian', 'Kama', 'Kama', 'Kama', 'Kama', 'Rosa', 'Kama', 'Kama',
#        'Kama', 'Canadian', 'Canadian', 'Kama', 'Rosa', 'Canadian', 'Kama',
#        'Canadian', 'Kama', 'Canadian', 'Rosa', 'Rosa', 'Rosa', 'Rosa',
#        'Kama', 'Rosa'], dtype=object)

# %%
# Comparación
np.equal(  y_predict , y_test.values )
# Out:
# array([ True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
# Score
np.equal(  y_predict , y_test.values ).sum() / len(y_predict)
# Out:
# np.float64(0.9)

# %%
# Score
modelo_MLP_tunned.score(X_test, y_test)
# Out:
# 0.9

# %% [markdown]
# | Modelo o clasificador   | Score |  Mean | Standard deviation  |  Parámetros de ajuste  |
# |---|---|---|---|---|
# |   MLP | 0.0  |     |        |    |
# |   MLP  Tunned| 0.0   |  0.0  |   0.0    |   max_depth: 0,  min_samples_leaf: 0   |

# %% [markdown]
# ### Guardar el modelo entrenado

# %%
import joblib

# %%
#Exportar el modelo
#joblib.dump(modelo, 'Ubicación del archivo .joblib')
joblib.dump(modelo_MLP_tunned, 'modelos/modelo_MLP_tunned_Semilla.joblib')
# Out:
# ['modelos/modelo_MLP_tunned_Semilla.joblib']

# %%
# Importar librerias
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions_DT_tunned = modelo_MLP_tunned.predict(X_test)
cm_DT_tunned = confusion_matrix(y_test, predictions_DT_tunned, labels=modelo_MLP_tunned.classes_)
disp_DT_tunned  = ConfusionMatrixDisplay(confusion_matrix=cm_DT_tunned, display_labels=modelo_MLP_tunned.classes_)
disp_DT_tunned.plot()
plt.title('Decision Tree')
plt.show()
